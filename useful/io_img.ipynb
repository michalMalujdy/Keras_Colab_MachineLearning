# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/michalMalujdy/machine-learning-colab/blob/master/useful/io_img.ipynb)

# %% [markdown]
# # Import an image file

# %% [markdown]
# With specified name (*example_img.jpg*) among many selected

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

filesDict = files.upload()
img = Image.open(BytesIO(filesDict['example_img.jpg']))
# Out:
#      <input type="file" id="files-ef925dc3-b7cf-4e10-bf5c-259cf7bf70cf" name="files[]" multiple disabled />
#      <output id="result-ef925dc3-b7cf-4e10-bf5c-259cf7bf70cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving example_img.jpg to example_img.jpg

# %% [markdown]
# ---

# %% [markdown]
# The first one from upload. Handy when uploaded single file.

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

filesDict = files.upload()
img = Image.open(BytesIO(filesDict.values()[0]))
# Out:
#      <input type="file" id="files-7621aa7f-00e9-4244-a6af-fa79f4847db2" name="files[]" multiple disabled />
#      <output id="result-7621aa7f-00e9-4244-a6af-fa79f4847db2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving example_img.jpg to example_img (1).jpg

# %% [markdown]
# ---

# %% [markdown]
# # Display the image with matplotlib

# %% [markdown]
# With default settings showing grid and axes numbers

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# With no gridlines and axes numbers

# %%
import matplotlib.pyplot as plt

plt.figure().gca().grid(False)
plt.axis('off')

plt.imshow(img)
plt.show()

# %% [markdown]
# ---
